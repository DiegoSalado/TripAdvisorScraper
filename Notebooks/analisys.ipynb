# %% [markdown]
# # Exploratory analysis for generate new variables

# %%
#import libreries
import pandas as pd
import numpy as np

# %%
#import data
restaurants=pd.read_csv('D:/DIEGO/Documents/CODIGO/challenge/Challenge repository/Data/restaurant_information.csv')
restaurants.shape
# Out:
# (6730, 14)

# %%
restaurants.head()
# Out:
#    Unnamed: 0  Popularity                           Name  Calfication  \
# 0           0           1    La Mansion Marriott Reforma          5.0
# 1           1           2                          Balta          5.0
# 2           2           3          Condimento Restaurant          5.0
# 3           3           4                     La Distral          5.0
# 4           4           5  Taquería y Restaurante Takotl          5.0
#
#    Num_reviwes             Phone  \
# 0       1086.0  +52 55 1102 7021
# 1        546.0  +52 55 8660 0500
# 2        757.0  +52 55 1102 7030
# 3        393.0  +52 55 5140 4100
# 4        167.0  +52 55 4778 6428
#
#                                              Webside   Latitude  Longitude  \
# 0     http://www.facebook.com/mansionmarriottreforma  19.428345 -99.164260
# 1  http://www.sofitel-mexico-city.com/restaurants...  19.428432 -99.165920
# 2  http://www.marriott.com/hotels/hotel-informati...  19.427828 -99.164024
# ...

# %% [markdown]
# Delete the 'Unnamed: 0' column

# %%
restaurants=restaurants.drop('Unnamed: 0', axis=1)
restaurants
# Out:
#       Popularity                            Name  Calfication  Num_reviwes  \
# 0              1     La Mansion Marriott Reforma          5.0       1086.0
# 1              2                           Balta          5.0        546.0
# 2              3           Condimento Restaurant          5.0        757.0
# 3              4                      La Distral          5.0        393.0
# 4              5   Taquería y Restaurante Takotl          5.0        167.0
# ...          ...                             ...          ...          ...
# 6725        6726            Santa #cocinacoqueta          NaN          NaN
# 6726        6727                         Momoxco          NaN          NaN
# 6727        6728                       La Strada          NaN          NaN
# 6728        6729                              BP          NaN          NaN
# 6729        6730  Taqueria Los Güeros de san Pío          NaN          NaN
#
# ...

# %% [markdown]
# For a page is imoprtant have a good calification, but not is the only.
#
# A page with 4 stars of calification with a many reviews have more impact than a page whit 5 stars but a review.
# Defining impact as follows, can we have a new variable from this.

# %%
restaurants['Impact']=(restaurants['Calfication']*restaurants['Num_reviwes'])
restaurants
# Out:
#       Popularity                            Name  Calfication  Num_reviwes  \
# 0              1     La Mansion Marriott Reforma          5.0       1086.0
# 1              2                           Balta          5.0        546.0
# 2              3           Condimento Restaurant          5.0        757.0
# 3              4                      La Distral          5.0        393.0
# 4              5   Taquería y Restaurante Takotl          5.0        167.0
# ...          ...                             ...          ...          ...
# 6725        6726            Santa #cocinacoqueta          NaN          NaN
# 6726        6727                         Momoxco          NaN          NaN
# 6727        6728                       La Strada          NaN          NaN
# 6728        6729                              BP          NaN          NaN
# 6729        6730  Taqueria Los Güeros de san Pío          NaN          NaN
#
# ...

# %% [markdown]
# Normalizing this variable

# %%
def minmax_norm(df):
    return (df - df.min()) / ( df.max() - df.min())

restaurants['Impact']=minmax_norm(restaurants['Impact'])
restaurants
# Out:
#       Popularity                            Name  Calfication  Num_reviwes  \
# 0              1     La Mansion Marriott Reforma          5.0       1086.0
# 1              2                           Balta          5.0        546.0
# 2              3           Condimento Restaurant          5.0        757.0
# 3              4                      La Distral          5.0        393.0
# 4              5   Taquería y Restaurante Takotl          5.0        167.0
# ...          ...                             ...          ...          ...
# 6725        6726            Santa #cocinacoqueta          NaN          NaN
# 6726        6727                         Momoxco          NaN          NaN
# 6727        6728                       La Strada          NaN          NaN
# 6728        6729                              BP          NaN          NaN
# 6729        6730  Taqueria Los Güeros de san Pío          NaN          NaN
#
# ...

# %%
restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6730 entries, 0 to 6729
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Popularity      6730 non-null   int64
#  1   Name            6730 non-null   object
#  2   Calfication     5209 non-null   float64
#  3   Num_reviwes     5209 non-null   float64
#  4   Phone           5756 non-null   object
#  5   Webside         5143 non-null   object
#  6   Latitude        6516 non-null   float64
#  7   Longitude       6516 non-null   float64
#  8   Type_food       5540 non-null   object
#  9   Comida          1940 non-null   float64
#  10  Servicio        1946 non-null   float64
#  11  Calidad/precio  1935 non-null   float64
#  12  Ambiente        674 non-null    float64
#  13  Impact          5209 non-null   float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 736.2+ KB
